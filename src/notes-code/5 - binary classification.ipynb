# %% [markdown]
# # Logistic Regression (binary classification)

# %% [markdown]
# ## Hypothesis space
# - Samples of dimension $ d $
# - Linearly separable
# $ \implies $
#   - $h_w(x)$ produces a linear discriminant of dimension $ d-1 $ (eg with two features we'll have a line)
#   - linear discriminant expressed as $ w^Tx + b = 0$
#   - if $ x_0 = 1 $ for every sample and $ w_0 = b $ then it reduces to $ w^Tx = 0$
# - Specifically we use the sigmoid function: $h_w(x) = g(w^Tx) = \frac{1}{1 + e^{-w^Tx}}$
#
# **So how do we predict**
# - Supposing we have two classes, 0 and 1
# - By imposing a threshold at - let's say - 0.5
#   - If $g(w^Tx) \geq 0.5$ then we predict class 1
#   - If $g(w^Tx) < 0.5$ then we predict class 0
#
# **Role of the bias?**
# - Since the bias doesn't interact directly with the features, it simply shifts the prediction even before it happens

# %%
import numpy as np
import matplotlib.pyplot as plt
def logisticFunction(t):
    return 1/(1+np.exp(-t))

t = np.arange(-5,5,0.01)
y = logisticFunction(t)

plt.plot(t,y); plt.grid()

# %% [markdown]
# ## How do we fit $w$ ?
#
# ### Likelihood
# - $ l(w) = p(y|x) = (h_w(x))^y * (1-h_w(x))^{1-y} $ where $y$ can be either $0$ or $1$
# - In words, given certain features, $y$ is $1$ with probability $h_w(x)$ and $0$ with probability $1-h_w(x)$
#
# **Using maximum likelihood**
# - At each step we update the weights in the direction of the gradient of the likelihood function, maximising it
# - Udate rule : $w_j = w_j + \alpha \frac{\partial l}{\partial w_j} = w_j + \alpha (y - h_w(x))x_j $
# - We would reach the same result by considering a squared error as loss function
#
# ### Loss function
# $ L(w) = \begin{cases} -log(h_w(x)) & \text{if} & y = 1 \\ -log(1 - h_w(x)) & \text{if} & y = 0 \end{cases}$
# OR ALSO
# $ L(w) = y(-log(h_w(x))) + (1-y)(-log(1 - h_w(x))) $

# %%
from ng.lab_utils_common import plotTwoLogLosses
plotTwoLogLosses()

# %%
from toolbox.datamodule import *
import torch
# https://raw.githubusercontent.com/jbrownlee/Datasets/master/haberman.names
# https://archive.ics.uci.edu/datasets

# load the dataset
# url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/haberman.csv'
# features = ["age","opYear","nodes","class"]
# dataset = DataLoader(url, features, num_train = 256, num_val = 50, batch_size = 16)
# dataset.summarize()
# print(dataset.dataframe)

# %%
from toolbox.datamodule import *
import pandas as pd

# load the dataset
dataframe = pd.read_csv("../data/diabetes_prediction_dataset.csv")
dataframe.head()

# dataset = DataLoader(path = "diabetes_prediction_dataset.csv", num_train = 256, num_val = 50, batch_size = 16)
# dataset.summarize()
# print(dataset.dataframe)

# %% [markdown]
# # Ng Example

# %%
from toolbox.base_models import *
from toolbox.trainer import *
from toolbox.datamodule import *

data = DataLoader(txtfile = "../data/log_reg.txt")
print("First five elements in X_train are:\n", data.X[:5])
print("Type of X_train:",type(data.X))
data.summarize()

model = LogisticRegressionScratch(input_dim = 2, lr=0.001)
# model = LogisticRegression(3, lr=0.01)
trainer = Trainer(max_epochs = 10000)
trainer.fit(model,data)
# Out:
# First five elements in X_train are:
#  tensor([[34.6237, 78.0247],
#         [30.2867, 43.8950],
#         [35.8474, 72.9022],
#         [60.1826, 86.3086],
#         [79.0327, 75.3444]])
# Type of X_train: <class 'torch.Tensor'>
# N Examples: 100
# N Inputs: 2
# N Classes: 2
# Classes: [0. 1.]
#  - Class 0.0: 40 (40.0)
#  - Class 1.0: 60 (60.0)
# Loss at epoch 1,batch 1: 4.782772541046143
#
# Loss at epoch 2,batch 1: 0.9942498207092285
#
# Loss at epoch 3,batch 1: 0.4216228723526001
#
# Loss at epoch 4,batch 1: 0.30580687522888184
#
# Loss at epoch 5,batch 1: 0.30547741055488586
#
# Loss at epoch 6,batch 1: 0.30546554923057556
#
# Loss at epoch 7,batch 1: 0.3054640591144562
#
# Loss at epoch 8,batch 1: 0.30546292662620544
#
# Loss at epoch 9,batch 1: 0.30546197295188904
#
# Loss at epoch 10,batch 1: 0.305461049079895
#
# Loss at epoch 11,batch 1: 0.30546021461486816
#
# Loss at epoch 12,batch 1: 0.3054594397544861
#
# Loss at epoch 13,batch 1: 0.3054587244987488
#
# Loss at epoch 14,batch 1: 0.30545803904533386
#
# Loss at epoch 15,batch 1: 0.3054574131965637
#
# Loss at epoch 16,batch 1: 0.30545684695243835
#
# Loss at epoch 17,batch 1: 0.305456280708313
#
# Loss at epoch 18,batch 1: 0.30545574426651
#
# Loss at epoch 19,batch 1: 0.30545517802238464
#
# Loss at epoch 20,batch 1: 0.30545470118522644
#
# Loss at epoch 21,batch 1: 0.30545419454574585
#
# Loss at epoch 22,batch 1: 0.30545374751091003
#
# Loss at epoch 23,batch 1: 0.30545327067375183
#
# Loss at epoch 24,batch 1: 0.3054528534412384
#
# Loss at epoch 25,batch 1: 0.305452436208725
#
# Loss at epoch 26,batch 1: 0.3054519593715668
#
# Loss at epoch 27,batch 1: 0.30545157194137573
#
# Loss at epoch 28,batch 1: 0.3054511547088623
#
# Loss at epoch 29,batch 1: 0.3054507374763489
#
# Loss at epoch 30,batch 1: 0.30545032024383545
#
# Loss at epoch 31,batch 1: 0.3054499924182892
#
# Loss at epoch 32,batch 1: 0.30544957518577576
#
# Loss at epoch 33,batch 1: 0.30544912815093994
#
# Loss at epoch 34,batch 1: 0.3054488003253937
#
# Loss at epoch 35,batch 1: 0.30544838309288025
#
# Loss at epoch 36,batch 1: 0.3054479956626892
#
# Loss at epoch 37,batch 1: 0.30544760823249817
#
# Loss at epoch 38,batch 1: 0.30544722080230713
#
# Loss at epoch 39,batch 1: 0.30544689297676086
#
# Loss at epoch 40,batch 1: 0.3054465055465698
#
# Loss at epoch 41,batch 1: 0.3054460883140564
#
# Loss at epoch 42,batch 1: 0.30544576048851013
#
# Loss at epoch 43,batch 1: 0.3054453730583191
#
# Loss at epoch 44,batch 1: 0.30544501543045044
#
# Loss at epoch 45,batch 1: 0.3054446280002594
#
# Loss at epoch 46,batch 1: 0.30544424057006836
#
# Loss at epoch 47,batch 1: 0.3054439127445221
#
# Loss at epoch 48,batch 1: 0.30544352531433105
#
# Loss at epoch 49,batch 1: 0.3054431676864624
#
# Loss at epoch 50,batch 1: 0.30544278025627136
#
# Loss at epoch 51,batch 1: 0.3054424226284027
#
# Loss at epoch 52,batch 1: 0.30544203519821167
#
# Loss at epoch 53,batch 1: 0.30544164776802063
#
# Loss at epoch 54,batch 1: 0.305441290140152
#
# Loss at epoch 55,batch 1: 0.3054409921169281
#
# Loss at epoch 56,batch 1: 0.3054405450820923
#
# Loss at epoch 57,batch 1: 0.305440217256546
#
# Loss at epoch 58,batch 1: 0.305439829826355
#
# Loss at epoch 59,batch 1: 0.3054395020008087
#
# Loss at epoch 60,batch 1: 0.3054390847682953
#
# Loss at epoch 61,batch 1: 0.30543869733810425
#
# Loss at epoch 62,batch 1: 0.305438369512558
#
# Loss at epoch 63,batch 1: 0.30543801188468933
#
# Loss at epoch 64,batch 1: 0.3054376542568207
#
# Loss at epoch 65,batch 1: 0.30543726682662964
#
# Loss at epoch 66,batch 1: 0.305436909198761
#
# Loss at epoch 67,batch 1: 0.30543649196624756
#
# Loss at epoch 68,batch 1: 0.3054361641407013
#
# Loss at epoch 69,batch 1: 0.30543577671051025
#
# Loss at epoch 70,batch 1: 0.3054354190826416
#
# Loss at epoch 71,batch 1: 0.30543506145477295
#
# Loss at epoch 72,batch 1: 0.3054346740245819
#
# Loss at epoch 73,batch 1: 0.30543434619903564
#
# Loss at epoch 74,batch 1: 0.3054339587688446
#
# Loss at epoch 75,batch 1: 0.30543357133865356
#
# Loss at epoch 76,batch 1: 0.3054331839084625
#
# Loss at epoch 77,batch 1: 0.30543282628059387
#
# Loss at epoch 78,batch 1: 0.3054324686527252
#
# Loss at epoch 79,batch 1: 0.3054320812225342
#
# Loss at epoch 80,batch 1: 0.3054317533969879
#
# Loss at epoch 81,batch 1: 0.30543139576911926
#
# Loss at epoch 82,batch 1: 0.3054310083389282
#
# Loss at epoch 83,batch 1: 0.3054306209087372
#
# Loss at epoch 84,batch 1: 0.3054302930831909
#
# Loss at epoch 85,batch 1: 0.3054299056529999
#
# Loss at epoch 86,batch 1: 0.3054295480251312
#
# Loss at epoch 87,batch 1: 0.3054291903972626
#
# Loss at epoch 88,batch 1: 0.30542880296707153
#
# Loss at epoch 89,batch 1: 0.3054284155368805
#
# Loss at epoch 90,batch 1: 0.30542808771133423
#
# Loss at epoch 91,batch 1: 0.3054277002811432
#
# Loss at epoch 92,batch 1: 0.30542731285095215
#
# Loss at epoch 93,batch 1: 0.3054269850254059
#
# Loss at epoch 94,batch 1: 0.30542659759521484
#
# Loss at epoch 95,batch 1: 0.3054262399673462
#
# Loss at epoch 96,batch 1: 0.30542582273483276
#
# Loss at epoch 97,batch 1: 0.3054254949092865
#
# Loss at epoch 98,batch 1: 0.30542510747909546
#
# Loss at epoch 99,batch 1: 0.3054247200489044
#
# Loss at epoch 100,batch 1: 0.30542439222335815
#
# Loss at epoch 101,batch 1: 0.3054240345954895
#
# Loss at epoch 102,batch 1: 0.30542364716529846
#
# Loss at epoch 103,batch 1: 0.3054232895374298
#
# Loss at epoch 104,batch 1: 0.30542290210723877
#
# Loss at epoch 105,batch 1: 0.3054225444793701
#
# Loss at epoch 106,batch 1: 0.30542218685150146
#
# Loss at epoch 107,batch 1: 0.3054217994213104
#
# Loss at epoch 108,batch 1: 0.30542147159576416
#
# Loss at epoch 109,batch 1: 0.30542105436325073
#
# Loss at epoch 110,batch 1: 0.3054206967353821
#
# Loss at epoch 111,batch 1: 0.3054203391075134
#
# Loss at epoch 112,batch 1: 0.3054199814796448
#
# Loss at epoch 113,batch 1: 0.3054196238517761
#
# Loss at epoch 114,batch 1: 0.30541926622390747
#
# Loss at epoch 115,batch 1: 0.30541887879371643
#
# Loss at epoch 116,batch 1: 0.3054185211658478
#
# Loss at epoch 117,batch 1: 0.3054181635379791
#
# Loss at epoch 118,batch 1: 0.3054177761077881
#
# Loss at epoch 119,batch 1: 0.30541741847991943
#
# Loss at epoch 120,batch 1: 0.3054170310497284
#
# Loss at epoch 121,batch 1: 0.30541667342185974
#
# Loss at epoch 122,batch 1: 0.3054162859916687
#
# Loss at epoch 123,batch 1: 0.30541595816612244
#
# Loss at epoch 124,batch 1: 0.305415540933609
#
# Loss at epoch 125,batch 1: 0.30541518330574036
#
# Loss at epoch 126,batch 1: 0.3054148554801941
#
# Loss at epoch 127,batch 1: 0.30541449785232544
#
# Loss at epoch 128,batch 1: 0.3054141104221344
#
# Loss at epoch 129,batch 1: 0.30541375279426575
#
# Loss at epoch 130,batch 1: 0.3054133653640747
#
# Loss at epoch 131,batch 1: 0.30541300773620605
#
# Loss at epoch 132,batch 1: 0.305412620306015
#
# Loss at epoch 133,batch 1: 0.30541226267814636
#
# Loss at epoch 134,batch 1: 0.3054119050502777
#
# Loss at epoch 135,batch 1: 0.30541151762008667
#
# Loss at epoch 136,batch 1: 0.305411159992218
#
# Loss at epoch 137,batch 1: 0.305410772562027
#
# Loss at epoch 138,batch 1: 0.3054104149341583
#
# Loss at epoch 139,batch 1: 0.30541008710861206
#
# Loss at epoch 140,batch 1: 0.305409699678421
#
# Loss at epoch 141,batch 1: 0.30540934205055237
#
# Loss at epoch 142,batch 1: 0.3054089844226837
#
# Loss at epoch 143,batch 1: 0.3054085969924927
#
# Loss at epoch 144,batch 1: 0.305408239364624
#
# Loss at epoch 145,batch 1: 0.30540788173675537
#
# Loss at epoch 146,batch 1: 0.30540749430656433
#
# Loss at epoch 147,batch 1: 0.3054071366786957
#
# Loss at epoch 148,batch 1: 0.30540674924850464
#
# Loss at epoch 149,batch 1: 0.305406391620636
#
# Loss at epoch 150,batch 1: 0.30540603399276733
#
# Loss at epoch 151,batch 1: 0.3054056465625763
#
# Loss at epoch 152,batch 1: 0.30540528893470764
#
# Loss at epoch 153,batch 1: 0.3054049015045166
#
# Loss at epoch 154,batch 1: 0.30540457367897034
#
# Loss at epoch 155,batch 1: 0.3054041862487793
#
# Loss at epoch 156,batch 1: 0.30540382862091064
#
# Loss at epoch 157,batch 1: 0.3054034411907196
#
# Loss at epoch 158,batch 1: 0.30540305376052856
#
# Loss at epoch 159,batch 1: 0.3054027259349823
#
# Loss at epoch 160,batch 1: 0.30540236830711365
#
# Loss at epoch 161,batch 1: 0.3054019808769226
#
# Loss at epoch 162,batch 1: 0.30540162324905396
#
# Loss at epoch 163,batch 1: 0.3054012656211853
#
# Loss at epoch 164,batch 1: 0.30540087819099426
#
# Loss at epoch 165,batch 1: 0.3054004907608032
#
# Loss at epoch 166,batch 1: 0.30540016293525696
#
# Loss at epoch 167,batch 1: 0.3053998053073883
#
# Loss at epoch 168,batch 1: 0.3053993880748749
#
# Loss at epoch 169,batch 1: 0.3053990602493286
#
# Loss at epoch 170,batch 1: 0.3053986430168152
#
# Loss at epoch 171,batch 1: 0.3053983449935913
#
# Loss at epoch 172,batch 1: 0.3053979277610779
#
# Loss at epoch 173,batch 1: 0.30539757013320923
#
# Loss at epoch 174,batch 1: 0.3053972125053406
#
# Loss at epoch 175,batch 1: 0.3053968548774719
#
# Loss at epoch 176,batch 1: 0.3053964674472809
#
# Loss at epoch 177,batch 1: 0.30539610981941223
#
# Loss at epoch 178,batch 1: 0.3053957521915436
#
# Loss at epoch 179,batch 1: 0.3053953945636749
#
# Loss at epoch 180,batch 1: 0.3053950071334839
#
# Loss at epoch 181,batch 1: 0.30539461970329285
#
# Loss at epoch 182,batch 1: 0.3053942918777466
#
# Loss at epoch 183,batch 1: 0.30539390444755554
#
# Loss at epoch 184,batch 1: 0.3053935170173645
#
# Loss at epoch 185,batch 1: 0.30539318919181824
#
# Loss at epoch 186,batch 1: 0.3053928017616272
#
# Loss at epoch 187,batch 1: 0.30539244413375854
#
# Loss at epoch 188,batch 1: 0.3053920865058899
#
# Loss at epoch 189,batch 1: 0.30539169907569885
#
# Loss at epoch 190,batch 1: 0.3053913414478302
#
# Loss at epoch 191,batch 1: 0.30539095401763916
#
# Loss at epoch 192,batch 1: 0.3053905963897705
#
# Loss at epoch 193,batch 1: 0.30539023876190186
#
# Loss at epoch 194,batch 1: 0.3053898513317108
#
# Loss at epoch 195,batch 1: 0.30538952350616455
#
# Loss at epoch 196,batch 1: 0.3053891360759735
#
# Loss at epoch 197,batch 1: 0.30538877844810486
#
# Loss at epoch 198,batch 1: 0.30538836121559143
#
# Loss at epoch 199,batch 1: 0.30538803339004517
#
# Loss at epoch 200,batch 1: 0.3053876459598541
#
# Loss at epoch 201,batch 1: 0.3053872883319855
#
# Loss at epoch 202,batch 1: 0.3053869307041168
#
# Loss at epoch 203,batch 1: 0.30538657307624817
#
# Loss at epoch 204,batch 1: 0.30538618564605713
#
# Loss at epoch 205,batch 1: 0.3053858280181885
#
# Loss at epoch 206,batch 1: 0.3053854703903198
#
# Loss at epoch 207,batch 1: 0.3053850829601288
#
# Loss at epoch 208,batch 1: 0.30538472533226013
#
# Loss at epoch 209,batch 1: 0.3053843677043915
#
# Loss at epoch 210,batch 1: 0.3053840100765228
#
# Loss at epoch 211,batch 1: 0.3053836524486542
#
# Loss at epoch 212,batch 1: 0.30538326501846313
#
# Loss at epoch 213,batch 1: 0.3053829073905945
#
# Loss at epoch 214,batch 1: 0.30538249015808105
#
# Loss at epoch 215,batch 1: 0.3053821325302124
#
# Loss at epoch 216,batch 1: 0.30538180470466614
#
# Loss at epoch 217,batch 1: 0.3053813874721527
#
# Loss at epoch 218,batch 1: 0.30538105964660645
#
# Loss at epoch 219,batch 1: 0.3053807020187378
#
# Loss at epoch 220,batch 1: 0.30538031458854675
#
# Loss at epoch 221,batch 1: 0.3053799569606781
#
# Loss at epoch 222,batch 1: 0.30537956953048706
#
# Loss at epoch 223,batch 1: 0.3053792119026184
#
# Loss at epoch 224,batch 1: 0.30537882447242737
#
# Loss at epoch 225,batch 1: 0.3053784966468811
#
# Loss at epoch 226,batch 1: 0.30537813901901245
#
# Loss at epoch 227,batch 1: 0.305377721786499
#
# Loss at epoch 228,batch 1: 0.30537736415863037
#
# Loss at epoch 229,batch 1: 0.30537697672843933
#
# Loss at epoch 230,batch 1: 0.3053766191005707
#
# Loss at epoch 231,batch 1: 0.3053762912750244
#
# Loss at epoch 232,batch 1: 0.30537593364715576
#
# Loss at epoch 233,batch 1: 0.3053755462169647
#
# Loss at epoch 234,batch 1: 0.3053751587867737
#
# Loss at epoch 235,batch 1: 0.30537480115890503
#
# Loss at epoch 236,batch 1: 0.3053744435310364
#
# Loss at epoch 237,batch 1: 0.3053740859031677
#
# Loss at epoch 238,batch 1: 0.3053736984729767
#
# Loss at epoch 239,batch 1: 0.30537334084510803
#
# Loss at epoch 240,batch 1: 0.305372953414917
#
# Loss at epoch 241,batch 1: 0.3053726255893707
#
# Loss at epoch 242,batch 1: 0.3053722381591797
#
# Loss at epoch 243,batch 1: 0.30537185072898865
#
# Loss at epoch 244,batch 1: 0.3053715229034424
#
# Loss at epoch 245,batch 1: 0.30537113547325134
#
# Loss at epoch 246,batch 1: 0.3053707480430603
#
# Loss at epoch 247,batch 1: 0.30537039041519165
#
# Loss at epoch 248,batch 1: 0.305370032787323
#
# Loss at epoch 249,batch 1: 0.30536967515945435
#
# Loss at epoch 250,batch 1: 0.3053692877292633
#
# Loss at epoch 251,batch 1: 0.30536893010139465
#
# Loss at epoch 252,batch 1: 0.305368572473526
#
# Loss at epoch 253,batch 1: 0.30536818504333496
#
# Loss at epoch 254,batch 1: 0.3053678274154663
#
# Loss at epoch 255,batch 1: 0.30536746978759766
#
# Loss at epoch 256,batch 1: 0.3053670823574066
#
# Loss at epoch 257,batch 1: 0.30536675453186035
#
# Loss at epoch 258,batch 1: 0.3053663671016693
#
# Loss at epoch 259,batch 1: 0.30536600947380066
#
# Loss at epoch 260,batch 1: 0.3053656220436096
#
# Loss at epoch 261,batch 1: 0.30536526441574097
#
# Loss at epoch 262,batch 1: 0.3053648769855499
#
# Loss at epoch 263,batch 1: 0.3053645193576813
#
# Loss at epoch 264,batch 1: 0.3053641617298126
#
# Loss at epoch 265,batch 1: 0.30536380410194397
#
# Loss at epoch 266,batch 1: 0.30536341667175293
#
# Loss at epoch 267,batch 1: 0.3053630590438843
#
# Loss at epoch 268,batch 1: 0.30536267161369324
#
# Loss at epoch 269,batch 1: 0.305362343788147
#
# Loss at epoch 270,batch 1: 0.30536195635795593
#
# Loss at epoch 271,batch 1: 0.3053615689277649
#
# Loss at epoch 272,batch 1: 0.30536124110221863
#
# Loss at epoch 273,batch 1: 0.3053608536720276
#
# Loss at epoch 274,batch 1: 0.30536046624183655
#
# Loss at epoch 275,batch 1: 0.3053601384162903
#
# Loss at epoch 276,batch 1: 0.30535978078842163
#
# Loss at epoch 277,batch 1: 0.3053593933582306
#
# Loss at epoch 278,batch 1: 0.30535900592803955
#
# Loss at epoch 279,batch 1: 0.3053586483001709
#
# Loss at epoch 280,batch 1: 0.30535829067230225
#
# Loss at epoch 281,batch 1: 0.3053579032421112
#
# Loss at epoch 282,batch 1: 0.30535754561424255
#
# Loss at epoch 283,batch 1: 0.3053571581840515
#
# Loss at epoch 284,batch 1: 0.30535683035850525
#
# Loss at epoch 285,batch 1: 0.3053564429283142
#
# Loss at epoch 286,batch 1: 0.30535605549812317
#
# Loss at epoch 287,batch 1: 0.3053557276725769
#
# Loss at epoch 288,batch 1: 0.30535534024238586
#
# Loss at epoch 289,batch 1: 0.3053549528121948
#
# Loss at epoch 290,batch 1: 0.30535459518432617
#
# Loss at epoch 291,batch 1: 0.3053542375564575
#
# Loss at epoch 292,batch 1: 0.30535387992858887
#
# Loss at epoch 293,batch 1: 0.3053535223007202
#
# Loss at epoch 294,batch 1: 0.30535316467285156
#
# Loss at epoch 295,batch 1: 0.3053527772426605
#
# Loss at epoch 296,batch 1: 0.3053523898124695
#
# Loss at epoch 297,batch 1: 0.3053520619869232
#
# Loss at epoch 298,batch 1: 0.3053516745567322
#
# Loss at epoch 299,batch 1: 0.30535128712654114
#
# Loss at epoch 300,batch 1: 0.3053509294986725
#
# Loss at epoch 301,batch 1: 0.30535057187080383
#
# Loss at epoch 302,batch 1: 0.3053501844406128
#
# Loss at epoch 303,batch 1: 0.30534982681274414
#
# Loss at epoch 304,batch 1: 0.3053494691848755
#
# Loss at epoch 305,batch 1: 0.30534911155700684
#
# Loss at epoch 306,batch 1: 0.3053487539291382
#
# Loss at epoch 307,batch 1: 0.30534839630126953
#
# Loss at epoch 308,batch 1: 0.3053480088710785
#
# Loss at epoch 309,batch 1: 0.30534762144088745
#
# Loss at epoch 310,batch 1: 0.3053472638130188
#
# Loss at epoch 311,batch 1: 0.30534690618515015
#
# Loss at epoch 312,batch 1: 0.3053465187549591
#
# Loss at epoch 313,batch 1: 0.30534613132476807
#
# Loss at epoch 314,batch 1: 0.3053458333015442
#
# Loss at epoch 315,batch 1: 0.30534544587135315
#
# Loss at epoch 316,batch 1: 0.3053450584411621
#
# Loss at epoch 317,batch 1: 0.30534470081329346
#
# Loss at epoch 318,batch 1: 0.3053443133831024
#
# Loss at epoch 319,batch 1: 0.30534398555755615
#
# Loss at epoch 320,batch 1: 0.3053435981273651
#
# Loss at epoch 321,batch 1: 0.30534324049949646
#
# Loss at epoch 322,batch 1: 0.3053428530693054
#
# Loss at epoch 323,batch 1: 0.30534249544143677
#
# Loss at epoch 324,batch 1: 0.3053421676158905
#
# Loss at epoch 325,batch 1: 0.30534178018569946
#
# Loss at epoch 326,batch 1: 0.30534136295318604
#
# Loss at epoch 327,batch 1: 0.3053410053253174
#
# Loss at epoch 328,batch 1: 0.30534064769744873
#
# Loss at epoch 329,batch 1: 0.30534031987190247
#
# Loss at epoch 330,batch 1: 0.3053399324417114
#
# Loss at epoch 331,batch 1: 0.3053395748138428
#
# Loss at epoch 332,batch 1: 0.30533918738365173
#
# Loss at epoch 333,batch 1: 0.3053388297557831
#
# Loss at epoch 334,batch 1: 0.30533847212791443
#
# Loss at epoch 335,batch 1: 0.3053380846977234
#
# Loss at epoch 336,batch 1: 0.30533772706985474
#
# Loss at epoch 337,batch 1: 0.3053373396396637
#
# Loss at epoch 338,batch 1: 0.30533698201179504
#
# Loss at epoch 339,batch 1: 0.305336594581604
#
# Loss at epoch 340,batch 1: 0.30533626675605774
#
# Loss at epoch 341,batch 1: 0.3053359091281891
#
# Loss at epoch 342,batch 1: 0.30533555150032043
#
# Loss at epoch 343,batch 1: 0.3053351640701294
#
# Loss at epoch 344,batch 1: 0.30533477663993835
#
# Loss at epoch 345,batch 1: 0.3053344488143921
#
# Loss at epoch 346,batch 1: 0.30533406138420105
#
# Loss at epoch 347,batch 1: 0.3053337037563324
#
# Loss at epoch 348,batch 1: 0.30533331632614136
#
# Loss at epoch 349,batch 1: 0.3053329586982727
#
# Loss at epoch 350,batch 1: 0.3053325414657593
#
# Loss at epoch 351,batch 1: 0.305332213640213
#
# Loss at epoch 352,batch 1: 0.30533185601234436
#
# Loss at epoch 353,batch 1: 0.3053314983844757
#
# Loss at epoch 354,batch 1: 0.30533111095428467
#
# Loss at epoch 355,batch 1: 0.305330753326416
#
# Loss at epoch 356,batch 1: 0.30533039569854736
#
# Loss at epoch 357,batch 1: 0.30532997846603394
#
# Loss at epoch 358,batch 1: 0.30532965064048767
#
# Loss at epoch 359,batch 1: 0.30532926321029663
#
# Loss at epoch 360,batch 1: 0.305328905582428
#
# Loss at epoch 361,batch 1: 0.3053285479545593
#
# Loss at epoch 362,batch 1: 0.3053281903266907
#
# Loss at epoch 363,batch 1: 0.305327832698822
#
# Loss at epoch 364,batch 1: 0.305327445268631
#
# Loss at epoch 365,batch 1: 0.30532705783843994
#
# Loss at epoch 366,batch 1: 0.3053267002105713
#
# Loss at epoch 367,batch 1: 0.30532634258270264
#
# Loss at epoch 368,batch 1: 0.3053259551525116
#
# Loss at epoch 369,batch 1: 0.30532559752464294
#
# Loss at epoch 370,batch 1: 0.3053252398967743
#
# Loss at epoch 371,batch 1: 0.305324912071228
#
# Loss at epoch 372,batch 1: 0.305324524641037
#
# Loss at epoch 373,batch 1: 0.30532413721084595
#
# Loss at epoch 374,batch 1: 0.3053237497806549
#
# Loss at epoch 375,batch 1: 0.30532342195510864
#
# Loss at epoch 376,batch 1: 0.3053230345249176
#
# Loss at epoch 377,batch 1: 0.30532264709472656
#
# Loss at epoch 378,batch 1: 0.3053222894668579
#
# Loss at epoch 379,batch 1: 0.30532196164131165
#
# Loss at epoch 380,batch 1: 0.3053215742111206
#
# Loss at epoch 381,batch 1: 0.30532124638557434
#
# Loss at epoch 382,batch 1: 0.3053208589553833
#
# Loss at epoch 383,batch 1: 0.3053204417228699
#
# Loss at epoch 384,batch 1: 0.3053201138973236
#
# Loss at epoch 385,batch 1: 0.3053196966648102
#
# Loss at epoch 386,batch 1: 0.30531933903694153
#
# Loss at epoch 387,batch 1: 0.30531901121139526
#
# Loss at epoch 388,batch 1: 0.3053186535835266
#
# Loss at epoch 389,batch 1: 0.30531826615333557
#
# Loss at epoch 390,batch 1: 0.3053179085254669
#
# Loss at epoch 391,batch 1: 0.3053175210952759
#
# Loss at epoch 392,batch 1: 0.3053171634674072
#
# Loss at epoch 393,batch 1: 0.3053168058395386
#
# Loss at epoch 394,batch 1: 0.30531641840934753
#
# Loss at epoch 395,batch 1: 0.30531609058380127
#
# Loss at epoch 396,batch 1: 0.30531570315361023
#
# Loss at epoch 397,batch 1: 0.3053153157234192
#
# Loss at epoch 398,batch 1: 0.3053149878978729
#
# Loss at epoch 399,batch 1: 0.3053146004676819
#
# Loss at epoch 400,batch 1: 0.30531421303749084
#
# Loss at epoch 401,batch 1: 0.3053138852119446
#
# Loss at epoch 402,batch 1: 0.3053135275840759
#
# Loss at epoch 403,batch 1: 0.3053131401538849
#
# Loss at epoch 404,batch 1: 0.30531275272369385
#
# Loss at epoch 405,batch 1: 0.3053123950958252
#
# Loss at epoch 406,batch 1: 0.30531203746795654
#
# Loss at epoch 407,batch 1: 0.3053116500377655
#
# Loss at epoch 408,batch 1: 0.30531129240989685
#
# Loss at epoch 409,batch 1: 0.3053109347820282
#
# Loss at epoch 410,batch 1: 0.30531054735183716
#
# Loss at epoch 411,batch 1: 0.3053101897239685
#
# Loss at epoch 412,batch 1: 0.30530983209609985
#
# Loss at epoch 413,batch 1: 0.3053094744682312
#
# Loss at epoch 414,batch 1: 0.30530908703804016
#
# Loss at epoch 415,batch 1: 0.3053087592124939
#
# Loss at epoch 416,batch 1: 0.30530837178230286
#
# Loss at epoch 417,batch 1: 0.3053080141544342
#
# Loss at epoch 418,batch 1: 0.30530762672424316
#
# Loss at epoch 419,batch 1: 0.3053072690963745
#
# Loss at epoch 420,batch 1: 0.30530688166618347
#
# Loss at epoch 421,batch 1: 0.3053065240383148
#
# Loss at epoch 422,batch 1: 0.3053061366081238
#
# Loss at epoch 423,batch 1: 0.3053057789802551
#
# Loss at epoch 424,batch 1: 0.30530545115470886
#
# Loss at epoch 425,batch 1: 0.30530503392219543
#
# Loss at epoch 426,batch 1: 0.3053046762943268
#
# Loss at epoch 427,batch 1: 0.30530431866645813
#
# Loss at epoch 428,batch 1: 0.3053039610385895
#
# Loss at epoch 429,batch 1: 0.30530357360839844
#
# Loss at epoch 430,batch 1: 0.3053032159805298
#
# Loss at epoch 431,batch 1: 0.30530285835266113
#
# Loss at epoch 432,batch 1: 0.3053025007247925
#
# Loss at epoch 433,batch 1: 0.30530211329460144
#
# Loss at epoch 434,batch 1: 0.3053017854690552
#
# Loss at epoch 435,batch 1: 0.30530136823654175
#
# Loss at epoch 436,batch 1: 0.3053010404109955
#
# Loss at epoch 437,batch 1: 0.30530062317848206
#
# Loss at epoch 438,batch 1: 0.3053002655506134
#
# Loss at epoch 439,batch 1: 0.30529987812042236
#
# Loss at epoch 440,batch 1: 0.3052995502948761
#
# Loss at epoch 441,batch 1: 0.30529919266700745
#
# Loss at epoch 442,batch 1: 0.3052988052368164
#
# Loss at epoch 443,batch 1: 0.30529841780662537
#
# Loss at epoch 444,batch 1: 0.3052980601787567
#
# Loss at epoch 445,batch 1: 0.30529773235321045
#
# Loss at epoch 446,batch 1: 0.3052973449230194
#
# Loss at epoch 447,batch 1: 0.30529698729515076
#
# Loss at epoch 448,batch 1: 0.3052965998649597
#
# Loss at epoch 449,batch 1: 0.30529624223709106
#
# Loss at epoch 450,batch 1: 0.3052959144115448
#
# Loss at epoch 451,batch 1: 0.30529555678367615
#
# Loss at epoch 452,batch 1: 0.3052951395511627
#
# Loss at epoch 453,batch 1: 0.30529481172561646
#
# Loss at epoch 454,batch 1: 0.3052944242954254
#
# Loss at epoch 455,batch 1: 0.30529406666755676
#
# Loss at epoch 456,batch 1: 0.3052937090396881
#
# Loss at epoch 457,batch 1: 0.30529332160949707
#
# Loss at epoch 458,batch 1: 0.3052929639816284
#
# Loss at epoch 459,batch 1: 0.3052925765514374
#
# Loss at epoch 460,batch 1: 0.3052922189235687
#
# Loss at epoch 461,batch 1: 0.3052918612957001
#
# Loss at epoch 462,batch 1: 0.30529147386550903
#
# Loss at epoch 463,batch 1: 0.305291086435318
#
# Loss at epoch 464,batch 1: 0.30529072880744934
#
# Loss at epoch 465,batch 1: 0.3052903711795807
#
# Loss at epoch 466,batch 1: 0.30529001355171204
#
# Loss at epoch 467,batch 1: 0.3052896559238434
#
# Loss at epoch 468,batch 1: 0.30528926849365234
#
# Loss at epoch 469,batch 1: 0.3052889108657837
#
# Loss at epoch 470,batch 1: 0.30528852343559265
#
# Loss at epoch 471,batch 1: 0.3052881956100464
#
# Loss at epoch 472,batch 1: 0.30528780817985535
#
# Loss at epoch 473,batch 1: 0.3052874207496643
#
# Loss at epoch 474,batch 1: 0.30528706312179565
#
# Loss at epoch 475,batch 1: 0.305286705493927
#
# Loss at epoch 476,batch 1: 0.30528634786605835
#
# Loss at epoch 477,batch 1: 0.3052859902381897
#
# Loss at epoch 478,batch 1: 0.30528560280799866
#
# Loss at epoch 479,batch 1: 0.3052852153778076
#
# Loss at epoch 480,batch 1: 0.30528488755226135
#
# Loss at epoch 481,batch 1: 0.3052845001220703
#
# Loss at epoch 482,batch 1: 0.30528414249420166
#
# Loss at epoch 483,batch 1: 0.305283784866333
#
# Loss at epoch 484,batch 1: 0.30528339743614197
#
# Loss at epoch 485,batch 1: 0.3052830100059509
#
# Loss at epoch 486,batch 1: 0.30528268218040466
#
# Loss at epoch 487,batch 1: 0.3052822947502136
#
# Loss at epoch 488,batch 1: 0.30528193712234497
#
# Loss at epoch 489,batch 1: 0.3052815794944763
#
# Loss at epoch 490,batch 1: 0.3052811920642853
#
# Loss at epoch 491,batch 1: 0.3052808344364166
#
# Loss at epoch 492,batch 1: 0.305280476808548
#
# Loss at epoch 493,batch 1: 0.3052801191806793
#
# Loss at epoch 494,batch 1: 0.3052797317504883
#
# Loss at epoch 495,batch 1: 0.30527937412261963
#
# Loss at epoch 496,batch 1: 0.305279016494751
#
# Loss at epoch 497,batch 1: 0.3052786588668823
#
# Loss at epoch 498,batch 1: 0.3052782714366913
#
# Loss at epoch 499,batch 1: 0.30527791380882263
#
# Loss at epoch 500,batch 1: 0.305277556180954
#
# Loss at epoch 501,batch 1: 0.30527716875076294
#
# Loss at epoch 502,batch 1: 0.3052768111228943
#
# Loss at epoch 503,batch 1: 0.30527642369270325
#
# Loss at epoch 504,batch 1: 0.3052760660648346
#
# Loss at epoch 505,batch 1: 0.30527573823928833
#
# Loss at epoch 506,batch 1: 0.3052753508090973
#
# Loss at epoch 507,batch 1: 0.30527496337890625
#
# Loss at epoch 508,batch 1: 0.3052746057510376
#
# Loss at epoch 509,batch 1: 0.30527421832084656
#
# Loss at epoch 510,batch 1: 0.3052738904953003
#
# Loss at epoch 511,batch 1: 0.30527350306510925
#
# Loss at epoch 512,batch 1: 0.3052731454372406
#
# Loss at epoch 513,batch 1: 0.30527278780937195
#
# Loss at epoch 514,batch 1: 0.3052724003791809
#
# Loss at epoch 515,batch 1: 0.30527204275131226
#
# Loss at epoch 516,batch 1: 0.3052716553211212
#
# Loss at epoch 517,batch 1: 0.30527129769325256
#
# Loss at epoch 518,batch 1: 0.3052709400653839
#
# Loss at epoch 519,batch 1: 0.30527055263519287
#
# Loss at epoch 520,batch 1: 0.3052701950073242
#
# Loss at epoch 521,batch 1: 0.30526983737945557
#
# Loss at epoch 522,batch 1: 0.3052694797515869
#
# Loss at epoch 523,batch 1: 0.3052690923213959
#
# Loss at epoch 524,batch 1: 0.3052687346935272
#
# Loss at epoch 525,batch 1: 0.30526837706565857
#
# Loss at epoch 526,batch 1: 0.3052680194377899
#
# Loss at epoch 527,batch 1: 0.3052676320075989
#
# Loss at epoch 528,batch 1: 0.3052672743797302
#
# Loss at epoch 529,batch 1: 0.3052669167518616
#
# Loss at epoch 530,batch 1: 0.30526652932167053
#
# Loss at epoch 531,batch 1: 0.3052661716938019
#
# Loss at epoch 532,batch 1: 0.3052658140659332
#
# Loss at epoch 533,batch 1: 0.3052654266357422
#
# Loss at epoch 534,batch 1: 0.30526506900787354
#
# Loss at epoch 535,batch 1: 0.3052646815776825
#
# Loss at epoch 536,batch 1: 0.30526432394981384
#
# Loss at epoch 537,batch 1: 0.3052639663219452
#
# Loss at epoch 538,batch 1: 0.30526357889175415
#
# Loss at epoch 539,batch 1: 0.3052632212638855
#
# Loss at epoch 540,batch 1: 0.30526286363601685
#
# Loss at epoch 541,batch 1: 0.3052624762058258
#
# Loss at epoch 542,batch 1: 0.30526211857795715
#
# Loss at epoch 543,batch 1: 0.3052617609500885
#
# Loss at epoch 544,batch 1: 0.30526140332221985
#
# Loss at epoch 545,batch 1: 0.3052610158920288
#
# Loss at epoch 546,batch 1: 0.30526065826416016
#
# Loss at epoch 547,batch 1: 0.3052603006362915
#
# Loss at epoch 548,batch 1: 0.30525994300842285
#
# Loss at epoch 549,batch 1: 0.3052595555782318
#
# Loss at epoch 550,batch 1: 0.30525919795036316
#
# Loss at epoch 551,batch 1: 0.3052588105201721
#
# Loss at epoch 552,batch 1: 0.30525845289230347
#
# Loss at epoch 553,batch 1: 0.3052580952644348
#
# Loss at epoch 554,batch 1: 0.3052577078342438
#
# Loss at epoch 555,batch 1: 0.3052573502063751
#
# Loss at epoch 556,batch 1: 0.30525699257850647
#
# Loss at epoch 557,batch 1: 0.3052566349506378
#
# Loss at epoch 558,batch 1: 0.30525627732276917
#
# Loss at epoch 559,batch 1: 0.30525586009025574
#
# Loss at epoch 560,batch 1: 0.3052555322647095
#
# Loss at epoch 561,batch 1: 0.30525511503219604
#
# Loss at epoch 562,batch 1: 0.3052547872066498
#
# Loss at epoch 563,batch 1: 0.30525442957878113
#
# Loss at epoch 564,batch 1: 0.3052540719509125
#
# Loss at epoch 565,batch 1: 0.30525368452072144
#
# Loss at epoch 566,batch 1: 0.3052533268928528
#
# Loss at epoch 567,batch 1: 0.30525293946266174
#
# Loss at epoch 568,batch 1: 0.3052525818347931
#
# Loss at epoch 569,batch 1: 0.30525222420692444
#
# Loss at epoch 570,batch 1: 0.3052518665790558
#
# Loss at epoch 571,batch 1: 0.30525147914886475
#
# Loss at epoch 572,batch 1: 0.3052511215209961
#
# Loss at epoch 573,batch 1: 0.30525073409080505
#
# Loss at epoch 574,batch 1: 0.3052503764629364
#
# Loss at epoch 575,batch 1: 0.30525004863739014
#
# Loss at epoch 576,batch 1: 0.3052496314048767
#
# Loss at epoch 577,batch 1: 0.30524930357933044
#
# Loss at epoch 578,batch 1: 0.3052489161491394
#
# Loss at epoch 579,batch 1: 0.30524855852127075
#
# Loss at epoch 580,batch 1: 0.3052481710910797
#
# Loss at epoch 581,batch 1: 0.30524784326553345
#
# Loss at epoch 582,batch 1: 0.3052474558353424
#
# Loss at epoch 583,batch 1: 0.30524706840515137
#
# Loss at epoch 584,batch 1: 0.3052467405796051
#
# Loss at epoch 585,batch 1: 0.30524638295173645
#
# Loss at epoch 586,batch 1: 0.3052459955215454
#
# Loss at epoch 587,batch 1: 0.30524563789367676
#
# Loss at epoch 588,batch 1: 0.3052452802658081
#
# Loss at epoch 589,batch 1: 0.30524489283561707
#
# Loss at epoch 590,batch 1: 0.3052445352077484
#
# Loss at epoch 591,batch 1: 0.3052441477775574
#
# Loss at epoch 592,batch 1: 0.3052437901496887
#
# Loss at epoch 593,batch 1: 0.3052434027194977
#
# Loss at epoch 594,batch 1: 0.30524304509162903
#
# Loss at epoch 595,batch 1: 0.3052426874637604
#
# Loss at epoch 596,batch 1: 0.3052423596382141
#
# Loss at epoch 597,batch 1: 0.30524197220802307
#
# Loss at epoch 598,batch 1: 0.3052416145801544
#
# Loss at epoch 599,batch 1: 0.3052412271499634
#
# Loss at epoch 600,batch 1: 0.30524083971977234
#
# Loss at epoch 601,batch 1: 0.3052404820919037
#
# Loss at epoch 602,batch 1: 0.30524012446403503
#
# Loss at epoch 603,batch 1: 0.3052397668361664
#
# Loss at epoch 604,batch 1: 0.30523937940597534
#
# Loss at epoch 605,batch 1: 0.3052390217781067
#
# Loss at epoch 606,batch 1: 0.30523866415023804
#
# Loss at epoch 607,batch 1: 0.3052382469177246
#
# Loss at epoch 608,batch 1: 0.30523791909217834
#
# Loss at epoch 609,batch 1: 0.3052375316619873
#
# Loss at epoch 610,batch 1: 0.30523720383644104
#
# Loss at epoch 611,batch 1: 0.3052367866039276
#
# Loss at epoch 612,batch 1: 0.30523645877838135
#
# Loss at epoch 613,batch 1: 0.3052360415458679
#
# Loss at epoch 614,batch 1: 0.30523571372032166
#
# Loss at epoch 615,batch 1: 0.305235356092453
#
# Loss at epoch 616,batch 1: 0.30523499846458435
#
# Loss at epoch 617,batch 1: 0.3052346110343933
#
# Loss at epoch 618,batch 1: 0.3052341938018799
#
# Loss at epoch 619,batch 1: 0.3052338659763336
#
# Loss at epoch 620,batch 1: 0.30523350834846497
#
# Loss at epoch 621,batch 1: 0.3052331507205963
#
# Loss at epoch 622,batch 1: 0.30523279309272766
#
# Loss at epoch 623,batch 1: 0.3052324056625366
#
# Loss at epoch 624,batch 1: 0.30523207783699036
#
# Loss at epoch 625,batch 1: 0.30523166060447693
#
# Loss at epoch 626,batch 1: 0.3052313029766083
#
# Loss at epoch 627,batch 1: 0.305230975151062
#
# Loss at epoch 628,batch 1: 0.30523058772087097
#
# Loss at epoch 629,batch 1: 0.30523020029067993
#
# Loss at epoch 630,batch 1: 0.3052298426628113
#
# Loss at epoch 631,batch 1: 0.3052294850349426
#
# Loss at epoch 632,batch 1: 0.3052290976047516
#
# Loss at epoch 633,batch 1: 0.3052287697792053
#
# Loss at epoch 634,batch 1: 0.3052283823490143
#
# Loss at epoch 635,batch 1: 0.305228054523468
#
# Loss at epoch 636,batch 1: 0.3052276372909546
#
# Loss at epoch 637,batch 1: 0.30522727966308594
#
# Loss at epoch 638,batch 1: 0.3052268922328949
#
# Loss at epoch 639,batch 1: 0.30522656440734863
#
# Loss at epoch 640,batch 1: 0.3052261769771576
#
# Loss at epoch 641,batch 1: 0.30522581934928894
#
# Loss at epoch 642,batch 1: 0.3052254617214203
#
# Loss at epoch 643,batch 1: 0.30522507429122925
#
# Loss at epoch 644,batch 1: 0.3052247166633606
#
# Loss at epoch 645,batch 1: 0.30522435903549194
#
# Loss at epoch 646,batch 1: 0.3052240014076233
#
# Loss at epoch 647,batch 1: 0.30522361397743225
#
# Loss at epoch 648,batch 1: 0.3052232265472412
#
# Loss at epoch 649,batch 1: 0.30522289872169495
#
# Loss at epoch 650,batch 1: 0.3052225112915039
#
# Loss at epoch 651,batch 1: 0.30522215366363525
#
# Loss at epoch 652,batch 1: 0.3052217960357666
#
# Loss at epoch 653,batch 1: 0.30522143840789795
#
# Loss at epoch 654,batch 1: 0.3052210211753845
#
# Loss at epoch 655,batch 1: 0.30522069334983826
#
# Loss at epoch 656,batch 1: 0.3052203357219696
#
# Loss at epoch 657,batch 1: 0.30521994829177856
#
# Loss at epoch 658,batch 1: 0.3052196204662323
#
# Loss at epoch 659,batch 1: 0.30521923303604126
#
# Loss at epoch 660,batch 1: 0.30521881580352783
#
# Loss at epoch 661,batch 1: 0.3052184581756592
#
# Loss at epoch 662,batch 1: 0.3052181303501129
#
# Loss at epoch 663,batch 1: 0.3052177429199219
#
# Loss at epoch 664,batch 1: 0.3052173852920532
#
# Loss at epoch 665,batch 1: 0.30521702766418457
#
# Loss at epoch 666,batch 1: 0.3052166700363159
#
# Loss at epoch 667,batch 1: 0.3052162826061249
#
# Loss at epoch 668,batch 1: 0.3052159249782562
#
# Loss at epoch 669,batch 1: 0.3052155673503876
#
# Loss at epoch 670,batch 1: 0.30521517992019653
#
# Loss at epoch 671,batch 1: 0.3052148222923279
#
# Loss at epoch 672,batch 1: 0.30521446466445923
#
# Loss at epoch 673,batch 1: 0.3052140772342682
#
# Loss at epoch 674,batch 1: 0.3052137494087219
#
# Loss at epoch 675,batch 1: 0.3052133321762085
#
# Loss at epoch 676,batch 1: 0.30521297454833984
#
# Loss at epoch 677,batch 1: 0.3052126169204712
#
# Loss at epoch 678,batch 1: 0.30521225929260254
#
# Loss at epoch 679,batch 1: 0.3052119016647339
#
# Loss at epoch 680,batch 1: 0.30521151423454285
#
# Loss at epoch 681,batch 1: 0.3052111566066742
#
# Loss at epoch 682,batch 1: 0.30521076917648315
#
# Loss at epoch 683,batch 1: 0.3052104115486145
#
# Loss at epoch 684,batch 1: 0.30521002411842346
#
# Loss at epoch 685,batch 1: 0.3052096664905548
#
# Loss at epoch 686,batch 1: 0.30520930886268616
#
# Loss at epoch 687,batch 1: 0.3052089214324951
#
# Loss at epoch 688,batch 1: 0.30520859360694885
#
# Loss at epoch 689,batch 1: 0.3052082359790802
#
# Loss at epoch 690,batch 1: 0.3052078187465668
#
# Loss at epoch 691,batch 1: 0.3052074909210205
#
# Loss at epoch 692,batch 1: 0.30520713329315186
#
# Loss at epoch 693,batch 1: 0.3052067458629608
#
# Loss at epoch 694,batch 1: 0.30520638823509216
#
# Loss at epoch 695,batch 1: 0.3052060008049011
#
# Loss at epoch 696,batch 1: 0.30520564317703247
#
# Loss at epoch 697,batch 1: 0.30520525574684143
#
# Loss at epoch 698,batch 1: 0.30520492792129517
#
# Loss at epoch 699,batch 1: 0.3052045404911041
#
# Loss at epoch 700,batch 1: 0.30520421266555786
#
# Loss at epoch 701,batch 1: 0.30520379543304443
#
# Loss at epoch 702,batch 1: 0.30520346760749817
#
# Loss at epoch 703,batch 1: 0.30520308017730713
#
# Loss at epoch 704,batch 1: 0.3052027225494385
#
# Loss at epoch 705,batch 1: 0.3052023649215698
#
# Loss at epoch 706,batch 1: 0.3052019774913788
#
# Loss at epoch 707,batch 1: 0.3052016496658325
#
# Loss at epoch 708,batch 1: 0.3052012324333191
#
# Loss at epoch 709,batch 1: 0.30520087480545044
#
# Loss at epoch 710,batch 1: 0.3052004873752594
#
# Loss at epoch 711,batch 1: 0.30520015954971313
#
# Loss at epoch 712,batch 1: 0.3051997423171997
#
# Loss at epoch 713,batch 1: 0.30519938468933105
#
# Loss at epoch 714,batch 1: 0.3051990568637848
#
# Loss at epoch 715,batch 1: 0.30519863963127136
#
# Loss at epoch 716,batch 1: 0.3051983118057251
#
# Loss at epoch 717,batch 1: 0.30519795417785645
#
# Loss at epoch 718,batch 1: 0.3051975667476654
#
# Loss at epoch 719,batch 1: 0.30519720911979675
#
# Loss at epoch 720,batch 1: 0.3051968514919281
#
# Loss at epoch 721,batch 1: 0.30519649386405945
#
# Loss at epoch 722,batch 1: 0.3051961064338684
#
# Loss at epoch 723,batch 1: 0.30519571900367737
#
# Loss at epoch 724,batch 1: 0.3051953911781311
#
# Loss at epoch 725,batch 1: 0.30519503355026245
#
# Loss at epoch 726,batch 1: 0.3051946759223938
#
# Loss at epoch 727,batch 1: 0.30519428849220276
#
# Loss at epoch 728,batch 1: 0.3051939010620117
#
# Loss at epoch 729,batch 1: 0.30519354343414307
#
# Loss at epoch 730,batch 1: 0.3051931858062744
#
# Loss at epoch 731,batch 1: 0.30519282817840576
#
# Loss at epoch 732,batch 1: 0.3051924407482147
#
# Loss at epoch 733,batch 1: 0.30519208312034607
#
# Loss at epoch 734,batch 1: 0.3051917254924774
#
# Loss at epoch 735,batch 1: 0.30519139766693115
#
# Loss at epoch 736,batch 1: 0.3051909804344177
#
# Loss at epoch 737,batch 1: 0.3051905930042267
#
# Loss at epoch 738,batch 1: 0.30519023537635803
#
# Loss at epoch 739,batch 1: 0.30518990755081177
#
# Loss at epoch 740,batch 1: 0.3051895201206207
#
# Loss at epoch 741,batch 1: 0.3051891326904297
#
# Loss at epoch 742,batch 1: 0.30518877506256104
#
# Loss at epoch 743,batch 1: 0.3051884174346924
#
# Loss at epoch 744,batch 1: 0.30518805980682373
#
# Loss at epoch 745,batch 1: 0.3051876723766327
#
# Loss at epoch 746,batch 1: 0.30518731474876404
#
# Loss at epoch 747,batch 1: 0.3051869571208954
#
# Loss at epoch 748,batch 1: 0.30518656969070435
#
# Loss at epoch 749,batch 1: 0.3051862418651581
#
# Loss at epoch 750,batch 1: 0.30518585443496704
#
# Loss at epoch 751,batch 1: 0.3051854968070984
#
# Loss at epoch 752,batch 1: 0.30518510937690735
#
# Loss at epoch 753,batch 1: 0.3051847517490387
#
# Loss at epoch 754,batch 1: 0.30518439412117004
#
# Loss at epoch 755,batch 1: 0.305184006690979
#
# Loss at epoch 756,batch 1: 0.30518364906311035
#
# Loss at epoch 757,batch 1: 0.3051832914352417
#
# Loss at epoch 758,batch 1: 0.30518293380737305
#
# Loss at epoch 759,batch 1: 0.305182546377182
#
# Loss at epoch 760,batch 1: 0.30518218874931335
#
# Loss at epoch 761,batch 1: 0.3051818311214447
#
# Loss at epoch 762,batch 1: 0.30518144369125366
#
# Loss at epoch 763,batch 1: 0.305181086063385
#
# Loss at epoch 764,batch 1: 0.30518072843551636
#
# Loss at epoch 765,batch 1: 0.3051803708076477
#
# Loss at epoch 766,batch 1: 0.30517998337745667
#
# Loss at epoch 767,batch 1: 0.305179625749588
#
# Loss at epoch 768,batch 1: 0.305179238319397
#
# Loss at epoch 769,batch 1: 0.3051789104938507
#
# Loss at epoch 770,batch 1: 0.30517852306365967
#
# Loss at epoch 771,batch 1: 0.305178165435791
#
# Loss at epoch 772,batch 1: 0.3051777780056
#
# Loss at epoch 773,batch 1: 0.30517739057540894
#
# Loss at epoch 774,batch 1: 0.30517706274986267
#
# Loss at epoch 775,batch 1: 0.305176705121994
#
# Loss at epoch 776,batch 1: 0.305176317691803
#
# Loss at epoch 777,batch 1: 0.3051759600639343
#
# Loss at epoch 778,batch 1: 0.3051756024360657
#
# Loss at epoch 779,batch 1: 0.30517521500587463
#
# Loss at epoch 780,batch 1: 0.305174857378006
#
# Loss at epoch 781,batch 1: 0.30517446994781494
#
# Loss at epoch 782,batch 1: 0.3051741123199463
#
# Loss at epoch 783,batch 1: 0.30517375469207764
#
# Loss at epoch 784,batch 1: 0.3051733672618866
#
# Loss at epoch 785,batch 1: 0.30517303943634033
#
# Loss at epoch 786,batch 1: 0.3051726222038269
#
# Loss at epoch 787,batch 1: 0.30517226457595825
#
# Loss at epoch 788,batch 1: 0.3051719069480896
#
# Loss at epoch 789,batch 1: 0.30517154932022095
#
# Loss at epoch 790,batch 1: 0.3051711618900299
#
# Loss at epoch 791,batch 1: 0.30517083406448364
#
# Loss at epoch 792,batch 1: 0.3051704466342926
#
# Loss at epoch 793,batch 1: 0.30517011880874634
#
# Loss at epoch 794,batch 1: 0.3051697313785553
#
# Loss at epoch 795,batch 1: 0.30516937375068665
#
# Loss at epoch 796,batch 1: 0.305169016122818
#
# Loss at epoch 797,batch 1: 0.30516862869262695
#
# Loss at epoch 798,batch 1: 0.3051682412624359
#
# Loss at epoch 799,batch 1: 0.30516788363456726
#
# Loss at epoch 800,batch 1: 0.3051674962043762
#
# Loss at epoch 801,batch 1: 0.30516713857650757
#
# Loss at epoch 802,batch 1: 0.3051667809486389
#
# Loss at epoch 803,batch 1: 0.30516642332077026
#
# Loss at epoch 804,batch 1: 0.3051660656929016
#
# Loss at epoch 805,batch 1: 0.30516567826271057
#
# Loss at epoch 806,batch 1: 0.3051653206348419
#
# Loss at epoch 807,batch 1: 0.3051649332046509
#
# Loss at epoch 808,batch 1: 0.3051646053791046
#
# Loss at epoch 809,batch 1: 0.3051642179489136
#
# Loss at epoch 810,batch 1: 0.30516383051872253
#
# Loss at epoch 811,batch 1: 0.30516350269317627
#
# Loss at epoch 812,batch 1: 0.3051631450653076
#
# Loss at epoch 813,batch 1: 0.3051627278327942
#
# Loss at epoch 814,batch 1: 0.3051624000072479
#
# Loss at epoch 815,batch 1: 0.3051620423793793
#
# Loss at epoch 816,batch 1: 0.30516165494918823
#
# Loss at epoch 817,batch 1: 0.30516132712364197
#
# Loss at epoch 818,batch 1: 0.30516090989112854
#
# Loss at epoch 819,batch 1: 0.3051605522632599
#
# Loss at epoch 820,batch 1: 0.30516016483306885
#
# Loss at epoch 821,batch 1: 0.3051598072052002
#
# Loss at epoch 822,batch 1: 0.30515947937965393
#
# Loss at epoch 823,batch 1: 0.3051590919494629
#
# Loss at epoch 824,batch 1: 0.30515873432159424
#
# Loss at epoch 825,batch 1: 0.3051583766937256
#
# Loss at epoch 826,batch 1: 0.30515795946121216
#
# Loss at epoch 827,batch 1: 0.3051576018333435
#
# Loss at epoch 828,batch 1: 0.30515724420547485
#
# Loss at epoch 829,batch 1: 0.3051569163799286
#
# Loss at epoch 830,batch 1: 0.30515652894973755
#
# Loss at epoch 831,batch 1: 0.3051561713218689
#
# Loss at epoch 832,batch 1: 0.30515578389167786
#
# Loss at epoch 833,batch 1: 0.3051554560661316
#
# Loss at epoch 834,batch 1: 0.30515503883361816
#
# Loss at epoch 835,batch 1: 0.3051547110080719
#
# Loss at epoch 836,batch 1: 0.30515432357788086
#
# Loss at epoch 837,batch 1: 0.3051539659500122
#
# Loss at epoch 838,batch 1: 0.30515357851982117
#
# Loss at epoch 839,batch 1: 0.3051532208919525
#
# Loss at epoch 840,batch 1: 0.30515286326408386
#
# Loss at epoch 841,batch 1: 0.3051525056362152
#
# Loss at epoch 842,batch 1: 0.30515211820602417
#
# Loss at epoch 843,batch 1: 0.3051517605781555
#
# Loss at epoch 844,batch 1: 0.30515140295028687
#
# Loss at epoch 845,batch 1: 0.3051510453224182
#
# Loss at epoch 846,batch 1: 0.30515068769454956
#
# Loss at epoch 847,batch 1: 0.3051503002643585
#
# Loss at epoch 848,batch 1: 0.30514994263648987
#
# Loss at epoch 849,batch 1: 0.3051495850086212
#
# Loss at epoch 850,batch 1: 0.3051491677761078
#
# Loss at epoch 851,batch 1: 0.3051488399505615
#
# Loss at epoch 852,batch 1: 0.3051484525203705
#
# Loss at epoch 853,batch 1: 0.30514809489250183
#
# Loss at epoch 854,batch 1: 0.3051477372646332
#
# Loss at epoch 855,batch 1: 0.3051473796367645
#
# Loss at epoch 856,batch 1: 0.3051469922065735
#
# Loss at epoch 857,batch 1: 0.30514660477638245
#
# Loss at epoch 858,batch 1: 0.3051462471485138
#
# Loss at epoch 859,batch 1: 0.30514585971832275
#
# Loss at epoch 860,batch 1: 0.3051455616950989
#
# Loss at epoch 861,batch 1: 0.30514517426490784
#
# Loss at epoch 862,batch 1: 0.3051448166370392
#
# Loss at epoch 863,batch 1: 0.30514442920684814
#
# Loss at epoch 864,batch 1: 0.3051440715789795
#
# Loss at epoch 865,batch 1: 0.30514371395111084
#
# Loss at epoch 866,batch 1: 0.3051433265209198
#
# Loss at epoch 867,batch 1: 0.30514296889305115
#
# Loss at epoch 868,batch 1: 0.3051425814628601
#
# Loss at epoch 869,batch 1: 0.30514222383499146
#
# Loss at epoch 870,batch 1: 0.3051418364048004
#
# Loss at epoch 871,batch 1: 0.30514150857925415
#
# Loss at epoch 872,batch 1: 0.3051411211490631
#
# Loss at epoch 873,batch 1: 0.30514079332351685
#
# Loss at epoch 874,batch 1: 0.3051403760910034
#
# Loss at epoch 875,batch 1: 0.30514004826545715
#
# Loss at epoch 876,batch 1: 0.3051396608352661
#
# Loss at epoch 877,batch 1: 0.30513930320739746
#
# Loss at epoch 878,batch 1: 0.3051389455795288
#
# Loss at epoch 879,batch 1: 0.30513855814933777
#
# Loss at epoch 880,batch 1: 0.3051382005214691
#
# Loss at epoch 881,batch 1: 0.3051378130912781
#
# Loss at epoch 882,batch 1: 0.3051374554634094
#
# Loss at epoch 883,batch 1: 0.30513709783554077
#
# Loss at epoch 884,batch 1: 0.30513671040534973
#
# Loss at epoch 885,batch 1: 0.30513638257980347
#
# Loss at epoch 886,batch 1: 0.3051359951496124
#
# Loss at epoch 887,batch 1: 0.3051356375217438
#
# Loss at epoch 888,batch 1: 0.3051352798938751
#
# Loss at epoch 889,batch 1: 0.3051348924636841
#
# Loss at epoch 890,batch 1: 0.30513453483581543
#
# Loss at epoch 891,batch 1: 0.3051341772079468
#
# Loss at epoch 892,batch 1: 0.30513378977775574
#
# Loss at epoch 893,batch 1: 0.3051334619522095
#
# Loss at epoch 894,batch 1: 0.30513304471969604
#
# Loss at epoch 895,batch 1: 0.3051327168941498
#
# Loss at epoch 896,batch 1: 0.30513232946395874
#
# Loss at epoch 897,batch 1: 0.3051320016384125
#
# Loss at epoch 898,batch 1: 0.30513161420822144
#
# Loss at epoch 899,batch 1: 0.3051312565803528
#
# Loss at epoch 900,batch 1: 0.30513086915016174
#
# Loss at epoch 901,batch 1: 0.3051305115222931
#
# Loss at epoch 902,batch 1: 0.30513012409210205
#
# Loss at epoch 903,batch 1: 0.3051297664642334
#
# Loss at epoch 904,batch 1: 0.30512940883636475
#
# Loss at epoch 905,batch 1: 0.3051290512084961
#
# Loss at epoch 906,batch 1: 0.30512866377830505
#
# Loss at epoch 907,batch 1: 0.3051283359527588
#
# Loss at epoch 908,batch 1: 0.30512797832489014
#
# Loss at epoch 909,batch 1: 0.3051275908946991
#
# Loss at epoch 910,batch 1: 0.30512720346450806
#
# Loss at epoch 911,batch 1: 0.3051268458366394
#
# Loss at epoch 912,batch 1: 0.30512645840644836
#
# Loss at epoch 913,batch 1: 0.3051261007785797
#
# Loss at epoch 914,batch 1: 0.30512574315071106
#
# Loss at epoch 915,batch 1: 0.30512535572052
#
# Loss at epoch 916,batch 1: 0.30512499809265137
#
# Loss at epoch 917,batch 1: 0.3051246702671051
#
# Loss at epoch 918,batch 1: 0.30512428283691406
#
# Loss at epoch 919,batch 1: 0.3051239252090454
#
# Loss at epoch 920,batch 1: 0.30512356758117676
#
# Loss at epoch 921,batch 1: 0.3051231801509857
#
# Loss at epoch 922,batch 1: 0.3051227927207947
#
# Loss at epoch 923,batch 1: 0.30512240529060364
#
# Loss at epoch 924,batch 1: 0.30512210726737976
#
# Loss at epoch 925,batch 1: 0.30512169003486633
#
# Loss at epoch 926,batch 1: 0.3051213324069977
#
# Loss at epoch 927,batch 1: 0.30512097477912903
#
# Loss at epoch 928,batch 1: 0.3051206171512604
#
# Loss at epoch 929,batch 1: 0.3051202893257141
#
# Loss at epoch 930,batch 1: 0.3051198720932007
#
# Loss at epoch 931,batch 1: 0.30511951446533203
#
# Loss at epoch 932,batch 1: 0.3051191568374634
#
# Loss at epoch 933,batch 1: 0.30511876940727234
#
# Loss at epoch 934,batch 1: 0.3051184117794037
#
# Loss at epoch 935,batch 1: 0.30511805415153503
#
# Loss at epoch 936,batch 1: 0.3051176369190216
#
# Loss at epoch 937,batch 1: 0.30511730909347534
#
# Loss at epoch 938,batch 1: 0.3051169514656067
#
# Loss at epoch 939,batch 1: 0.30511656403541565
#
# Loss at epoch 940,batch 1: 0.305116206407547
#
# Loss at epoch 941,batch 1: 0.30511584877967834
#
# Loss at epoch 942,batch 1: 0.3051154613494873
#
# Loss at epoch 943,batch 1: 0.30511513352394104
#
# Loss at epoch 944,batch 1: 0.3051147758960724
#
# Loss at epoch 945,batch 1: 0.30511438846588135
#
# Loss at epoch 946,batch 1: 0.3051140308380127
#
# Loss at epoch 947,batch 1: 0.30511364340782166
#
# Loss at epoch 948,batch 1: 0.305113285779953
#
# Loss at epoch 949,batch 1: 0.30511292815208435
#
# Loss at epoch 950,batch 1: 0.3051125407218933
#
# Loss at epoch 951,batch 1: 0.30511221289634705
#
# Loss at epoch 952,batch 1: 0.3051117956638336
#
# Loss at epoch 953,batch 1: 0.30511146783828735
#
# Loss at epoch 954,batch 1: 0.3051110804080963
#
# Loss at epoch 955,batch 1: 0.30511072278022766
#
# Loss at epoch 956,batch 1: 0.3051103353500366
#
# Loss at epoch 957,batch 1: 0.30511000752449036
#
# Loss at epoch 958,batch 1: 0.3051096200942993
#
# Loss at epoch 959,batch 1: 0.30510926246643066
#
# Loss at epoch 960,batch 1: 0.305108904838562
#
# Loss at epoch 961,batch 1: 0.30510851740837097
#
# Loss at epoch 962,batch 1: 0.3051081895828247
#
# Loss at epoch 963,batch 1: 0.30510780215263367
#
# Loss at epoch 964,batch 1: 0.305107444524765
#
# Loss at epoch 965,batch 1: 0.305107057094574
#
# Loss at epoch 966,batch 1: 0.30510666966438293
#
# Loss at epoch 967,batch 1: 0.30510634183883667
#
# Loss at epoch 968,batch 1: 0.305105984210968
#
# Loss at epoch 969,batch 1: 0.305105596780777
#
# Loss at epoch 970,batch 1: 0.3051052391529083
#
# Loss at epoch 971,batch 1: 0.3051048517227173
#
# Loss at epoch 972,batch 1: 0.30510449409484863
#
# Loss at epoch 973,batch 1: 0.30510413646698
#
# Loss at epoch 974,batch 1: 0.30510377883911133
#
# Loss at epoch 975,batch 1: 0.3051033914089203
#
# Loss at epoch 976,batch 1: 0.305103063583374
#
# Loss at epoch 977,batch 1: 0.305102676153183
#
# Loss at epoch 978,batch 1: 0.30510231852531433
#
# Loss at epoch 979,batch 1: 0.3051019310951233
#
# Loss at epoch 980,batch 1: 0.30510157346725464
#
# Loss at epoch 981,batch 1: 0.305101215839386
#
# Loss at epoch 982,batch 1: 0.30510082840919495
#
# Loss at epoch 983,batch 1: 0.3051004707813263
#
# Loss at epoch 984,batch 1: 0.30510008335113525
#
# Loss at epoch 985,batch 1: 0.305099755525589
#
# Loss at epoch 986,batch 1: 0.30509936809539795
#
# Loss at epoch 987,batch 1: 0.3050990402698517
#
# Loss at epoch 988,batch 1: 0.30509865283966064
#
# Loss at epoch 989,batch 1: 0.3050982356071472
#
# Loss at epoch 990,batch 1: 0.30509787797927856
#
# Loss at epoch 991,batch 1: 0.3050975501537323
#
# Loss at epoch 992,batch 1: 0.30509719252586365
#
# Loss at epoch 993,batch 1: 0.3050968050956726
#
# Loss at epoch 994,batch 1: 0.30509641766548157
#
# Loss at epoch 995,batch 1: 0.3050960600376129
#
# Loss at epoch 996,batch 1: 0.30509570240974426
#
# Loss at epoch 997,batch 1: 0.3050953149795532
#
# Loss at epoch 998,batch 1: 0.30509495735168457
#
# Loss at epoch 999,batch 1: 0.3050945997238159
#
# Loss at epoch 1000,batch 1: 0.3050942122936249
#
# Loss at epoch 1001,batch 1: 0.3050938844680786
#
# Loss at epoch 1002,batch 1: 0.3050934672355652
#
# Loss at epoch 1003,batch 1: 0.30509310960769653
#
# Loss at epoch 1004,batch 1: 0.3050927519798279
#
# Loss at epoch 1005,batch 1: 0.30509239435195923
#
# Loss at epoch 1006,batch 1: 0.30509206652641296
#
# Loss at epoch 1007,batch 1: 0.3050916790962219
#
# Loss at epoch 1008,batch 1: 0.3050912916660309
#
# ...
#
# Loss at epoch 9671,batch 1: 0.3019629716873169
#
# Loss at epoch 9672,batch 1: 0.30196261405944824
#
# Loss at epoch 9673,batch 1: 0.3019622564315796
#
# Loss at epoch 9674,batch 1: 0.30196189880371094
#
# Loss at epoch 9675,batch 1: 0.3019615411758423
#
# Loss at epoch 9676,batch 1: 0.30196118354797363
#
# Loss at epoch 9677,batch 1: 0.301960825920105
#
# Loss at epoch 9678,batch 1: 0.30196046829223633
#
# Loss at epoch 9679,batch 1: 0.30196014046669006
#
# Loss at epoch 9680,batch 1: 0.301959753036499
#
# Loss at epoch 9681,batch 1: 0.301959365606308
#
# Loss at epoch 9682,batch 1: 0.3019590675830841
#
# Loss at epoch 9683,batch 1: 0.30195868015289307
#
# Loss at epoch 9684,batch 1: 0.3019583523273468
#
# Loss at epoch 9685,batch 1: 0.30195796489715576
#
# Loss at epoch 9686,batch 1: 0.3019576370716095
#
# Loss at epoch 9687,batch 1: 0.30195724964141846
#
# Loss at epoch 9688,batch 1: 0.3019568920135498
#
# Loss at epoch 9689,batch 1: 0.30195653438568115
#
# Loss at epoch 9690,batch 1: 0.3019562065601349
#
# Loss at epoch 9691,batch 1: 0.30195581912994385
#
# Loss at epoch 9692,batch 1: 0.3019554615020752
#
# Loss at epoch 9693,batch 1: 0.30195513367652893
#
# Loss at epoch 9694,batch 1: 0.3019547760486603
#
# Loss at epoch 9695,batch 1: 0.3019544184207916
#
# Loss at epoch 9696,batch 1: 0.301954060792923
#
# Loss at epoch 9697,batch 1: 0.30195367336273193
#
# Loss at epoch 9698,batch 1: 0.30195334553718567
#
# Loss at epoch 9699,batch 1: 0.3019530177116394
#
# Loss at epoch 9700,batch 1: 0.30195263028144836
#
# Loss at epoch 9701,batch 1: 0.3019522726535797
#
# Loss at epoch 9702,batch 1: 0.30195191502571106
#
# Loss at epoch 9703,batch 1: 0.3019515573978424
#
# Loss at epoch 9704,batch 1: 0.30195122957229614
#
# Loss at epoch 9705,batch 1: 0.3019508719444275
#
# Loss at epoch 9706,batch 1: 0.3019505441188812
#
# Loss at epoch 9707,batch 1: 0.3019501566886902
#
# Loss at epoch 9708,batch 1: 0.30194976925849915
#
# Loss at epoch 9709,batch 1: 0.3019494116306305
#
# Loss at epoch 9710,batch 1: 0.30194908380508423
#
# Loss at epoch 9711,batch 1: 0.3019486963748932
#
# Loss at epoch 9712,batch 1: 0.3019483685493469
#
# Loss at epoch 9713,batch 1: 0.30194801092147827
#
# Loss at epoch 9714,batch 1: 0.3019476532936096
#
# Loss at epoch 9715,batch 1: 0.30194729566574097
#
# Loss at epoch 9716,batch 1: 0.3019469678401947
#
# Loss at epoch 9717,batch 1: 0.3019465506076813
#
# Loss at epoch 9718,batch 1: 0.3019462525844574
#
# Loss at epoch 9719,batch 1: 0.30194586515426636
#
# Loss at epoch 9720,batch 1: 0.3019455373287201
#
# Loss at epoch 9721,batch 1: 0.30194514989852905
#
# Loss at epoch 9722,batch 1: 0.3019448220729828
#
# Loss at epoch 9723,batch 1: 0.30194443464279175
#
# Loss at epoch 9724,batch 1: 0.3019440770149231
#
# Loss at epoch 9725,batch 1: 0.30194374918937683
#
# Loss at epoch 9726,batch 1: 0.3019433915615082
#
# Loss at epoch 9727,batch 1: 0.30194300413131714
#
# Loss at epoch 9728,batch 1: 0.3019426465034485
#
# Loss at epoch 9729,batch 1: 0.3019423186779022
#
# Loss at epoch 9730,batch 1: 0.30194196105003357
#
# Loss at epoch 9731,batch 1: 0.3019416332244873
#
# Loss at epoch 9732,batch 1: 0.30194124579429626
#
# Loss at epoch 9733,batch 1: 0.3019408881664276
#
# Loss at epoch 9734,batch 1: 0.30194053053855896
#
# Loss at epoch 9735,batch 1: 0.3019401729106903
#
# Loss at epoch 9736,batch 1: 0.30193984508514404
#
# Loss at epoch 9737,batch 1: 0.301939457654953
#
# Loss at epoch 9738,batch 1: 0.30193912982940674
#
# Loss at epoch 9739,batch 1: 0.3019387722015381
#
# Loss at epoch 9740,batch 1: 0.30193841457366943
#
# Loss at epoch 9741,batch 1: 0.3019380569458008
#
# Loss at epoch 9742,batch 1: 0.30193769931793213
#
# Loss at epoch 9743,batch 1: 0.3019373416900635
#
# Loss at epoch 9744,batch 1: 0.3019369840621948
#
# Loss at epoch 9745,batch 1: 0.30193662643432617
#
# Loss at epoch 9746,batch 1: 0.3019362688064575
#
# Loss at epoch 9747,batch 1: 0.30193591117858887
#
# Loss at epoch 9748,batch 1: 0.3019355535507202
#
# Loss at epoch 9749,batch 1: 0.3019351661205292
#
# Loss at epoch 9750,batch 1: 0.3019348382949829
#
# Loss at epoch 9751,batch 1: 0.30193448066711426
#
# Loss at epoch 9752,batch 1: 0.301934152841568
#
# Loss at epoch 9753,batch 1: 0.30193376541137695
#
# Loss at epoch 9754,batch 1: 0.3019334077835083
#
# Loss at epoch 9755,batch 1: 0.30193305015563965
#
# Loss at epoch 9756,batch 1: 0.301932692527771
#
# Loss at epoch 9757,batch 1: 0.30193233489990234
#
# Loss at epoch 9758,batch 1: 0.3019319772720337
#
# Loss at epoch 9759,batch 1: 0.30193161964416504
#
# Loss at epoch 9760,batch 1: 0.3019312918186188
#
# Loss at epoch 9761,batch 1: 0.3019309341907501
#
# Loss at epoch 9762,batch 1: 0.30193057656288147
#
# Loss at epoch 9763,batch 1: 0.30193018913269043
#
# Loss at epoch 9764,batch 1: 0.30192986130714417
#
# Loss at epoch 9765,batch 1: 0.3019294738769531
#
# Loss at epoch 9766,batch 1: 0.30192917585372925
#
# Loss at epoch 9767,batch 1: 0.3019288182258606
#
# Loss at epoch 9768,batch 1: 0.30192846059799194
#
# Loss at epoch 9769,batch 1: 0.3019280731678009
#
# Loss at epoch 9770,batch 1: 0.30192771553993225
#
# Loss at epoch 9771,batch 1: 0.3019273281097412
#
# Loss at epoch 9772,batch 1: 0.30192700028419495
#
# Loss at epoch 9773,batch 1: 0.30192670226097107
#
# Loss at epoch 9774,batch 1: 0.30192631483078003
#
# Loss at epoch 9775,batch 1: 0.3019259572029114
#
# Loss at epoch 9776,batch 1: 0.3019256293773651
#
# Loss at epoch 9777,batch 1: 0.3019252419471741
#
# Loss at epoch 9778,batch 1: 0.3019248843193054
#
# Loss at epoch 9779,batch 1: 0.30192452669143677
#
# Loss at epoch 9780,batch 1: 0.3019241392612457
#
# Loss at epoch 9781,batch 1: 0.30192381143569946
#
# Loss at epoch 9782,batch 1: 0.3019234538078308
#
# Loss at epoch 9783,batch 1: 0.30192309617996216
#
# Loss at epoch 9784,batch 1: 0.3019227385520935
#
# Loss at epoch 9785,batch 1: 0.30192241072654724
#
# Loss at epoch 9786,batch 1: 0.3019220232963562
#
# Loss at epoch 9787,batch 1: 0.30192166566848755
#
# Loss at epoch 9788,batch 1: 0.3019213378429413
#
# Loss at epoch 9789,batch 1: 0.30192098021507263
#
# Loss at epoch 9790,batch 1: 0.3019205927848816
#
# Loss at epoch 9791,batch 1: 0.3019202649593353
#
# Loss at epoch 9792,batch 1: 0.3019199073314667
#
# Loss at epoch 9793,batch 1: 0.301919549703598
#
# Loss at epoch 9794,batch 1: 0.301919162273407
#
# Loss at epoch 9795,batch 1: 0.3019188344478607
#
# Loss at epoch 9796,batch 1: 0.30191847681999207
#
# Loss at epoch 9797,batch 1: 0.3019181191921234
#
# Loss at epoch 9798,batch 1: 0.30191779136657715
#
# Loss at epoch 9799,batch 1: 0.3019174337387085
#
# Loss at epoch 9800,batch 1: 0.30191704630851746
#
# Loss at epoch 9801,batch 1: 0.3019166886806488
#
# Loss at epoch 9802,batch 1: 0.30191636085510254
#
# Loss at epoch 9803,batch 1: 0.3019160032272339
#
# Loss at epoch 9804,batch 1: 0.30191561579704285
#
# Loss at epoch 9805,batch 1: 0.3019152879714966
#
# Loss at epoch 9806,batch 1: 0.30191490054130554
#
# Loss at epoch 9807,batch 1: 0.3019145727157593
#
# Loss at epoch 9808,batch 1: 0.3019142150878906
#
# Loss at epoch 9809,batch 1: 0.3019138276576996
#
# Loss at epoch 9810,batch 1: 0.3019134998321533
#
# Loss at epoch 9811,batch 1: 0.30191314220428467
#
# Loss at epoch 9812,batch 1: 0.301912784576416
#
# Loss at epoch 9813,batch 1: 0.30191242694854736
#
# Loss at epoch 9814,batch 1: 0.3019120693206787
#
# Loss at epoch 9815,batch 1: 0.30191171169281006
#
# Loss at epoch 9816,batch 1: 0.3019113540649414
#
# Loss at epoch 9817,batch 1: 0.30191099643707275
#
# Loss at epoch 9818,batch 1: 0.3019106686115265
#
# Loss at epoch 9819,batch 1: 0.30191028118133545
#
# Loss at epoch 9820,batch 1: 0.3019099235534668
#
# Loss at epoch 9821,batch 1: 0.30190956592559814
#
# Loss at epoch 9822,batch 1: 0.3019092082977295
#
# Loss at epoch 9823,batch 1: 0.30190885066986084
#
# Loss at epoch 9824,batch 1: 0.3019084930419922
#
# Loss at epoch 9825,batch 1: 0.30190813541412354
#
# Loss at epoch 9826,batch 1: 0.3019077777862549
#
# Loss at epoch 9827,batch 1: 0.3019074499607086
#
# Loss at epoch 9828,batch 1: 0.30190709233283997
#
# Loss at epoch 9829,batch 1: 0.3019067347049713
#
# Loss at epoch 9830,batch 1: 0.30190637707710266
#
# Loss at epoch 9831,batch 1: 0.301906019449234
#
# Loss at epoch 9832,batch 1: 0.30190566182136536
#
# Loss at epoch 9833,batch 1: 0.3019053339958191
#
# Loss at epoch 9834,batch 1: 0.30190497636795044
#
# Loss at epoch 9835,batch 1: 0.3019045889377594
#
# Loss at epoch 9836,batch 1: 0.30190423130989075
#
# Loss at epoch 9837,batch 1: 0.3019038736820221
#
# Loss at epoch 9838,batch 1: 0.30190354585647583
#
# Loss at epoch 9839,batch 1: 0.3019031584262848
#
# Loss at epoch 9840,batch 1: 0.30190280079841614
#
# Loss at epoch 9841,batch 1: 0.3019024729728699
#
# Loss at epoch 9842,batch 1: 0.3019021153450012
#
# Loss at epoch 9843,batch 1: 0.3019017279148102
#
# Loss at epoch 9844,batch 1: 0.30190137028694153
#
# Loss at epoch 9845,batch 1: 0.30190104246139526
#
# Loss at epoch 9846,batch 1: 0.3019006848335266
#
# Loss at epoch 9847,batch 1: 0.30190032720565796
#
# Loss at epoch 9848,batch 1: 0.3018999695777893
#
# Loss at epoch 9849,batch 1: 0.30189961194992065
#
# Loss at epoch 9850,batch 1: 0.301899254322052
#
# Loss at epoch 9851,batch 1: 0.30189892649650574
#
# Loss at epoch 9852,batch 1: 0.3018985390663147
#
# Loss at epoch 9853,batch 1: 0.30189818143844604
#
# Loss at epoch 9854,batch 1: 0.3018978238105774
#
# Loss at epoch 9855,batch 1: 0.30189746618270874
#
# Loss at epoch 9856,batch 1: 0.3018971383571625
#
# Loss at epoch 9857,batch 1: 0.3018967807292938
#
# Loss at epoch 9858,batch 1: 0.3018963932991028
#
# Loss at epoch 9859,batch 1: 0.3018960654735565
#
# Loss at epoch 9860,batch 1: 0.30189570784568787
#
# Loss at epoch 9861,batch 1: 0.3018953502178192
#
# Loss at epoch 9862,batch 1: 0.30189499258995056
#
# Loss at epoch 9863,batch 1: 0.3018946349620819
#
# Loss at epoch 9864,batch 1: 0.30189427733421326
#
# Loss at epoch 9865,batch 1: 0.3018939197063446
#
# Loss at epoch 9866,batch 1: 0.30189359188079834
#
# Loss at epoch 9867,batch 1: 0.3018932044506073
#
# Loss at epoch 9868,batch 1: 0.30189284682273865
#
# Loss at epoch 9869,batch 1: 0.3018925189971924
#
# Loss at epoch 9870,batch 1: 0.30189213156700134
#
# Loss at epoch 9871,batch 1: 0.3018917739391327
#
# Loss at epoch 9872,batch 1: 0.3018914461135864
#
# Loss at epoch 9873,batch 1: 0.3018910586833954
#
# Loss at epoch 9874,batch 1: 0.3018907308578491
#
# Loss at epoch 9875,batch 1: 0.30189037322998047
#
# Loss at epoch 9876,batch 1: 0.30188998579978943
#
# Loss at epoch 9877,batch 1: 0.30188965797424316
#
# Loss at epoch 9878,batch 1: 0.3018893003463745
#
# Loss at epoch 9879,batch 1: 0.30188891291618347
#
# Loss at epoch 9880,batch 1: 0.3018885850906372
#
# Loss at epoch 9881,batch 1: 0.30188822746276855
#
# Loss at epoch 9882,batch 1: 0.3018878698348999
#
# Loss at epoch 9883,batch 1: 0.30188754200935364
#
# Loss at epoch 9884,batch 1: 0.3018871545791626
#
# Loss at epoch 9885,batch 1: 0.30188682675361633
#
# Loss at epoch 9886,batch 1: 0.3018864691257477
#
# Loss at epoch 9887,batch 1: 0.30188608169555664
#
# Loss at epoch 9888,batch 1: 0.3018857538700104
#
# Loss at epoch 9889,batch 1: 0.3018854260444641
#
# Loss at epoch 9890,batch 1: 0.30188503861427307
#
# Loss at epoch 9891,batch 1: 0.3018846809864044
#
# Loss at epoch 9892,batch 1: 0.30188432335853577
#
# Loss at epoch 9893,batch 1: 0.3018839955329895
#
# Loss at epoch 9894,batch 1: 0.30188360810279846
#
# Loss at epoch 9895,batch 1: 0.3018832504749298
#
# Loss at epoch 9896,batch 1: 0.30188286304473877
#
# Loss at epoch 9897,batch 1: 0.3018825352191925
#
# Loss at epoch 9898,batch 1: 0.30188214778900146
#
# Loss at epoch 9899,batch 1: 0.3018818199634552
#
# Loss at epoch 9900,batch 1: 0.30188149213790894
#
# Loss at epoch 9901,batch 1: 0.3018811047077179
#
# Loss at epoch 9902,batch 1: 0.30188074707984924
#
# Loss at epoch 9903,batch 1: 0.301880419254303
#
# Loss at epoch 9904,batch 1: 0.3018800616264343
#
# Loss at epoch 9905,batch 1: 0.3018797039985657
#
# Loss at epoch 9906,batch 1: 0.30187931656837463
#
# Loss at epoch 9907,batch 1: 0.30187898874282837
#
# Loss at epoch 9908,batch 1: 0.3018786609172821
#
# Loss at epoch 9909,batch 1: 0.30187827348709106
#
# Loss at epoch 9910,batch 1: 0.3018779158592224
#
# Loss at epoch 9911,batch 1: 0.30187755823135376
#
# Loss at epoch 9912,batch 1: 0.3018772006034851
#
# Loss at epoch 9913,batch 1: 0.30187684297561646
#
# Loss at epoch 9914,batch 1: 0.3018764853477478
#
# Loss at epoch 9915,batch 1: 0.30187615752220154
#
# Loss at epoch 9916,batch 1: 0.3018757700920105
#
# Loss at epoch 9917,batch 1: 0.30187541246414185
#
# Loss at epoch 9918,batch 1: 0.3018750846385956
#
# Loss at epoch 9919,batch 1: 0.30187472701072693
#
# Loss at epoch 9920,batch 1: 0.3018743395805359
#
# Loss at epoch 9921,batch 1: 0.30187398195266724
#
# Loss at epoch 9922,batch 1: 0.3018736243247986
#
# Loss at epoch 9923,batch 1: 0.3018732964992523
#
# Loss at epoch 9924,batch 1: 0.30187293887138367
#
# Loss at epoch 9925,batch 1: 0.3018725514411926
#
# Loss at epoch 9926,batch 1: 0.301872193813324
#
# Loss at epoch 9927,batch 1: 0.3018718659877777
#
# Loss at epoch 9928,batch 1: 0.30187147855758667
#
# Loss at epoch 9929,batch 1: 0.3018711507320404
#
# Loss at epoch 9930,batch 1: 0.30187079310417175
#
# Loss at epoch 9931,batch 1: 0.3018704354763031
#
# Loss at epoch 9932,batch 1: 0.30187010765075684
#
# Loss at epoch 9933,batch 1: 0.3018697500228882
#
# Loss at epoch 9934,batch 1: 0.30186939239501953
#
# Loss at epoch 9935,batch 1: 0.3018690049648285
#
# Loss at epoch 9936,batch 1: 0.30186864733695984
#
# Loss at epoch 9937,batch 1: 0.3018683195114136
#
# Loss at epoch 9938,batch 1: 0.30186793208122253
#
# Loss at epoch 9939,batch 1: 0.30186763405799866
#
# Loss at epoch 9940,batch 1: 0.3018672466278076
#
# Loss at epoch 9941,batch 1: 0.30186688899993896
#
# Loss at epoch 9942,batch 1: 0.3018665313720703
#
# Loss at epoch 9943,batch 1: 0.30186617374420166
#
# Loss at epoch 9944,batch 1: 0.301865816116333
#
# Loss at epoch 9945,batch 1: 0.30186545848846436
#
# Loss at epoch 9946,batch 1: 0.3018651008605957
#
# Loss at epoch 9947,batch 1: 0.30186474323272705
#
# Loss at epoch 9948,batch 1: 0.3018643856048584
#
# Loss at epoch 9949,batch 1: 0.30186405777931213
#
# Loss at epoch 9950,batch 1: 0.3018636703491211
#
# Loss at epoch 9951,batch 1: 0.30186331272125244
#
# Loss at epoch 9952,batch 1: 0.3018629550933838
#
# Loss at epoch 9953,batch 1: 0.3018626272678375
#
# Loss at epoch 9954,batch 1: 0.30186226963996887
#
# Loss at epoch 9955,batch 1: 0.30186188220977783
#
# Loss at epoch 9956,batch 1: 0.3018615245819092
#
# Loss at epoch 9957,batch 1: 0.3018611967563629
#
# Loss at epoch 9958,batch 1: 0.3018608093261719
#
# Loss at epoch 9959,batch 1: 0.3018604516983032
#
# Loss at epoch 9960,batch 1: 0.30186012387275696
#
# Loss at epoch 9961,batch 1: 0.3018597662448883
#
# Loss at epoch 9962,batch 1: 0.30185943841934204
#
# Loss at epoch 9963,batch 1: 0.3018590807914734
#
# Loss at epoch 9964,batch 1: 0.30185872316360474
#
# Loss at epoch 9965,batch 1: 0.3018583357334137
#
# Loss at epoch 9966,batch 1: 0.30185797810554504
#
# Loss at epoch 9967,batch 1: 0.3018576502799988
#
# Loss at epoch 9968,batch 1: 0.3018572926521301
#
# Loss at epoch 9969,batch 1: 0.3018569052219391
#
# Loss at epoch 9970,batch 1: 0.3018565773963928
#
# Loss at epoch 9971,batch 1: 0.30185621976852417
#
# Loss at epoch 9972,batch 1: 0.3018558621406555
#
# Loss at epoch 9973,batch 1: 0.30185553431510925
#
# Loss at epoch 9974,batch 1: 0.3018551766872406
#
# Loss at epoch 9975,batch 1: 0.30185478925704956
#
# Loss at epoch 9976,batch 1: 0.3018544316291809
#
# Loss at epoch 9977,batch 1: 0.30185407400131226
#
# Loss at epoch 9978,batch 1: 0.301853746175766
#
# Loss at epoch 9979,batch 1: 0.30185335874557495
#
# Loss at epoch 9980,batch 1: 0.3018530309200287
#
# Loss at epoch 9981,batch 1: 0.30185264348983765
#
# Loss at epoch 9982,batch 1: 0.30185234546661377
#
# Loss at epoch 9983,batch 1: 0.30185195803642273
#
# Loss at epoch 9984,batch 1: 0.3018515706062317
#
# Loss at epoch 9985,batch 1: 0.3018512427806854
#
# Loss at epoch 9986,batch 1: 0.3018508553504944
#
# Loss at epoch 9987,batch 1: 0.30185049772262573
#
# Loss at epoch 9988,batch 1: 0.3018501400947571
#
# Loss at epoch 9989,batch 1: 0.3018498420715332
#
# Loss at epoch 9990,batch 1: 0.30184948444366455
#
# Loss at epoch 9991,batch 1: 0.3018490970134735
#
# Loss at epoch 9992,batch 1: 0.30184873938560486
#
# Loss at epoch 9993,batch 1: 0.3018484115600586
#
# Loss at epoch 9994,batch 1: 0.30184802412986755
#
# Loss at epoch 9995,batch 1: 0.3018476665019989
#
# Loss at epoch 9996,batch 1: 0.30184733867645264
#
# Loss at epoch 9997,batch 1: 0.3018469512462616
#
# Loss at epoch 9998,batch 1: 0.30184659361839294
#
# Loss at epoch 9999,batch 1: 0.3018462657928467
#
# Loss at epoch 10000,batch 1: 0.3018459379673004

# %% [markdown]
# # Penguins

# %%
import tensorflow_datasets as tfds
import torch
# You can see the load documentation here: https://www.tensorflow.org/datasets
# The dataset itself is described here: https://www.tensorflow.org/datasets/catalog/penguins
penguins = tfds.load('penguins', as_supervised=True, split='train')

# %%
# By default, the Dataset object is an iterator over the elements.
# The instructions below extract the underlying tensors.
X, y = penguins.batch(500).get_single_element() #gets first 500 elements
X, y = X.numpy(), y.numpy()
# One row is an example, one column a feature of the input.
X.shape, X[0]

# %%
# We split in a training set and a test set using the train_test_split utility from sklearn.
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, stratify=y)
Xtrain = torch.from_numpy(Xtrain).float()
Xtest = torch.from_numpy(Xtest).float()
ytrain = torch.from_numpy(ytrain).long()
ytest = torch.from_numpy(ytest).long()

# %% [markdown]
# # Perceptron (binary classification)

# %% [markdown]
# ## Hypothesis space
# - Same linear discriminant as logistic regression
# - But the $h_w(x)$ is different, namely

# %% [markdown]
#  $ h_w(x) = g(w^Tx) = \begin{cases} 1 & \text{if} & w^Tx \geq 0 \\ 0 & \text{if} & w^Tx < 0 \end{cases}$

# %% [markdown]
# - So perceptron is basically logistic regression with a linear decision boundary
#
# **So how do we predict?**
#
# - We predict by projecting the samples on the vector of weights and looking at the sign of that number $wx$
# - Looking at the sign and deciding is the actication function (which is nonlinear)
#
# ## How do we fit $w$ ?
# - We can use squared loss $ E = \frac{1}{2} \sum_{i=1}^n (y_i - wx_i)^2 $
#
# **Using gradient descent**
# - At each step we update the weights in the direction of the negative gradient of the loss function
# - Same update rule as with logistic regression
